# %% [markdown]
# <a href="https://colab.research.google.com/github/gopika-vit/-AI-DS-/blob/main/hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import ttest_ind

# Load data
data = pd.read_csv("/content/drive/MyDrive/student-mat[1].csv")
paid_yes = data[data["paid"] == "yes"]["G3"]
paid_no = data[data["paid"] == "no"]["G3"]

# Perform Welch's t-test
t_stat, p_value = ttest_ind(paid_yes, paid_no, equal_var=False)
print(f"t-statistic: {t_stat}, p-value: {p_value}")

# Decision
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: Significant difference in means.")
else:
    print("Fail to reject the null hypothesis: No significant difference.")
# Out:
# t-statistic: 2.0830813622505953,
#  p-value: 0.03790084419239712
# Reject the null hypothesis: Significant difference in means.
